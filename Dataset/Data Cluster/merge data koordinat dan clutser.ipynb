# %%
import pandas as pd

# %%
cluster = pd.read_csv("cluster.csv")
cluster.head()
# Out:
#    ID Kabupaten  No. Tanggal Kejadian Kejadian  \
# 0          1601    1       31/12/2021   BANJIR
# 1          1111    2       31/12/2021   BANJIR
# 2          1213    3       31/12/2021   BANJIR
# 3          1221    4       31/12/2021   BANJIR
# 4          3374    5       31/12/2021   BANJIR
#
#                                               Lokasi          Kabupaten  \
# 0               Kec. Lubuk Batang Ds. Gunung Meraksa  OGAN KOMERING ULU
# 1  Kec. Dewantara Gp. Tambon Tunong Gp.  Uteun ge...         ACEH UTARA
# 2               Kec. Pematang Jaya Ds. Damar Condong            LANGKAT
# 3  ● Kec. Batang Lobu Sutam - Ds. Tanjung Baru - ...       PADANG LAWAS
# 4  Kec. Gayamsari Kel. Tambakrejo Kel. Kaligawe K...      KOTA SEMARANG
#
#            Provinsi Kronologi & Dokumentasi  \
# 0  SUMATERA SELATAN                     NaN
# 1              ACEH                     NaN
# 2    SUMATERA UTARA                     NaN
# 3    SUMATERA UTARA                     NaN
# ...

# %%
koordinat = pd.read_csv("koordinat.csv")
koordinat.head()
# Out:
#    Unnamed: 0                            Location  \
# 0           0  OGAN KOMERING ULU,SUMATERA SELATAN
# 1           1                     ACEH UTARA,ACEH
# 2           2              LANGKAT,SUMATERA UTARA
# 3           3         PADANG LAWAS,SUMATERA UTARA
# 4           4           KOTA SEMARANG,JAWA TENGAH
#
#                                                  loc  \
# 0     Ogan Komering Ulu, Sumatera Selatan, Indonesia
# 1                        Aceh Utara, Aceh, Indonesia
# 2                 Langkat, Sumatera Utara, Indonesia
# 3     Padang Lawas, Sumatera Utara, 22774, Indonesia
# 4  Gang Kelapa Gading, Wates, Ngaliyan, Kota Sema...
#
#                                           point       lat         lon  \
# 0         (-4.1101012, 104.00828376734528, 0.0) -4.110101  104.008284
# 1           (4.99119405, 97.1587368058996, 0.0)  4.991194   97.158737
# 2           (3.8290501, 98.24827397454335, 0.0)  3.829050   98.248274
# ...

# %%
koordinat.shape
# Out:
# (2968, 7)

# %%
koordinat = koordinat.drop(columns = ["Unnamed: 0"])

# %%
koordinat.isnull().sum()
# Out:
# Location    0
# loc         9
# point       9
# lat         9
# lon         9
# altitude    9
# dtype: int64

# %%
cluster.isnull().sum()
# Out:
# ID Kabupaten                  0
# No.                           0
# Tanggal Kejadian              0
# Kejadian                      0
# Lokasi                       32
# Kabupaten                     0
# Provinsi                      0
# Kronologi & Dokumentasi    2734
# Penyebab                    482
# Meninggal                     0
# Hilang                        0
# Terluka                       0
# Rumah Rusak                   0
# Fasum Rusak                   0
# korban_jiwa                   0
# kerusakan                     0
# Clusters                      0
# cluster                       0
# dtype: int64

# %%
koordinat = koordinat.reset_index(drop=True)
cluster = cluster.reset_index(drop=True)

# %%
koordinat.head()
# Out:
#                              Location  \
# 0  OGAN KOMERING ULU,SUMATERA SELATAN
# 1                     ACEH UTARA,ACEH
# 2              LANGKAT,SUMATERA UTARA
# 3         PADANG LAWAS,SUMATERA UTARA
# 4           KOTA SEMARANG,JAWA TENGAH
#
#                                                  loc  \
# 0     Ogan Komering Ulu, Sumatera Selatan, Indonesia
# 1                        Aceh Utara, Aceh, Indonesia
# 2                 Langkat, Sumatera Utara, Indonesia
# 3     Padang Lawas, Sumatera Utara, 22774, Indonesia
# 4  Gang Kelapa Gading, Wates, Ngaliyan, Kota Sema...
#
#                                           point       lat         lon  \
# 0         (-4.1101012, 104.00828376734528, 0.0) -4.110101  104.008284
# 1           (4.99119405, 97.1587368058996, 0.0)  4.991194   97.158737
# 2           (3.8290501, 98.24827397454335, 0.0)  3.829050   98.248274
# 3  (1.1565902000000001, 99.81080407051435, 0.0)  1.156590   99.810804
# ...

# %%
cluster.head()
# Out:
#    ID Kabupaten  No. Tanggal Kejadian Kejadian  \
# 0          1601    1       31/12/2021   BANJIR
# 1          1111    2       31/12/2021   BANJIR
# 2          1213    3       31/12/2021   BANJIR
# 3          1221    4       31/12/2021   BANJIR
# 4          3374    5       31/12/2021   BANJIR
#
#                                               Lokasi          Kabupaten  \
# 0               Kec. Lubuk Batang Ds. Gunung Meraksa  OGAN KOMERING ULU
# 1  Kec. Dewantara Gp. Tambon Tunong Gp.  Uteun ge...         ACEH UTARA
# 2               Kec. Pematang Jaya Ds. Damar Condong            LANGKAT
# 3  ● Kec. Batang Lobu Sutam - Ds. Tanjung Baru - ...       PADANG LAWAS
# 4  Kec. Gayamsari Kel. Tambakrejo Kel. Kaligawe K...      KOTA SEMARANG
#
#            Provinsi Kronologi & Dokumentasi  \
# 0  SUMATERA SELATAN                     NaN
# 1              ACEH                     NaN
# 2    SUMATERA UTARA                     NaN
# 3    SUMATERA UTARA                     NaN
# ...
